# %%
import datetime as dt
import talib as ta
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader.data as pdr
import pandas as pd
import yfinance as yf

# %%
run RSI.ipynb
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
code = 'AAPL'
start_time = '2021-01-01'
end_time ='2024-03-24'
period = 14

# for RSI
data = yf.download(code, start = start_time, end = end_time)
data['RSI'] = ta.RSI(data['Close'], period)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# get the stocks symbols 
import pandas as pd
from yahoo_fin import stock_info as si
df1 = pd.DataFrame( si.tickers_sp500() )
# df2 = pd.DataFrame( si.tickers_nasdaq() ) 49??
# df3 = pd.DataFrame( si.tickers_dow() ) 30
print(df1)
# Out:
#         0
# 0       A
# 1     AAL
# 2    AAPL
# 3    ABBV
# 4    ABNB
# ..    ...
# 498   XYL
# 499   YUM
# 500   ZBH
# 501  ZBRA
# 502   ZTS
#
# [503 rows x 1 columns]

# %%
symbol_list
# Out:
# ['A',
#  'AAL',
#  'AAPL',
#  'ABBV',
#  'ABNB',
#  'ABT',
#  'ACGL',
#  'ACN',
#  'ADBE',
#  'ADI',
#  'ADM',
#  'ADP',
#  'ADSK',
#  'AEE',
#  'AEP',
#  'AES',
#  'AFL',
#  'AIG',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'ALB',
#  'ALGN',
#  'ALL',
#  'ALLE',
#  'AMAT',
#  'AMCR',
#  'AMD',
#  'AME',
#  'AMGN',
#  'AMP',
#  'AMT',
#  'AMZN',
#  'ANET',
#  'ANSS',
#  'AON',
#  'AOS',
#  'APA',
#  'APD',
#  'APH',
#  'APTV',
#  'ARE',
#  'ATO',
#  'AVB',
#  'AVGO',
#  'AVY',
#  'AWK',
#  'AXON',
#  'AXP',
#  'AZO',
#  'BA',
#  'BAC',
#  'BALL',
#  'BAX',
#  'BBWI',
#  'BBY',
#  'BDX',
#  'BEN',
#  'BF-B',
#  'BG',
#  'BIIB',
#  'BIO',
#  'BK',
#  'BKNG',
#  'BKR',
#  'BLDR',
#  'BLK',
#  'BMY',
#  'BR',
#  'BRK-B',
#  'BRO',
#  'BSX',
#  'BWA',
#  'BX',
#  'BXP',
#  'C',
#  'CAG',
#  'CAH',
#  'CARR',
#  'CAT',
#  'CB',
#  'CBOE',
#  'CBRE',
#  'CCI',
#  'CCL',
#  'CDNS',
#  'CDW',
#  'CE',
#  'CEG',
#  'CF',
#  'CFG',
#  'CHD',
#  'CHRW',
#  'CHTR',
#  'CI',
#  'CINF',
#  'CL',
#  'CLX',
# ...

# %%
start_timRSI_list024-01-01'
end_time ='2024-04-03'
period = 14


RSI_list=[]
MACD_list=[]
for symbol in symbol_list:
    data = yf.download(symbol, start = start_time, end = end_time)
    if RSI(period, data): #RSI < 30
        RSI_list.append(symbol)
    # if MACD():
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
for i in RSI_list:
    print(i)
# Out:
# GL
# HUM
# LULU
# NKE
# UNH
# ZTS

# %%
# Out:
# 30
# 30
